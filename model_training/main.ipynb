# %% [markdown]
# # 학습 관련 준비

# %% [markdown]
# ## Google Drive 마운트
# - 학습 데이터 사용
# - 모델링 관련 파일 사용을 위함

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 폴더 이동 model_trainning으로
# %cd /content/drive/MyDrive/gdgline-AI/model_training
# Out:
# /content/drive/MyDrive/gdgline-AI/model_training

# %%
# 현재 폴더 확인
# %pwd
# Out:
# '/content/drive/MyDrive/gdgline-AI/model_training'

# %%
# 환경 의존성 설치
# !pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/gdgline-AI/model_training
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (2.5.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (0.20.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from model_training==0.1) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from model_training==0.1)
#   Downloading ultralytics_thop-2.0.11-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->model_training==0.1) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->model_training==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->model_training==0.1) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->model_training==0.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->model_training==0.1) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->model_training==0.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->model_training==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->model_training==0.1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->model_training==0.1) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->model_training==0.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->model_training==0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->model_training==0.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->model_training==0.1) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->model_training==0.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->model_training==0.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->model_training==0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->model_training==0.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->model_training==0.1) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->model_training==0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->model_training==0.1) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->model_training==0.1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->model_training==0.1) (3.0.2)
# Downloading ultralytics_thop-2.0.11-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, model_training
#   Running setup.py develop for model_training
# Successfully installed model_training-0.1 ultralytics-thop-2.0.11

# %%
# parser args를 사용하여 변수할당 해줄 것임
import argparse
parser = argparse.ArgumentParser()

args, unknown = parser.parse_known_args()

# %% [markdown]
# # 세팅 환경 확인

# %%
args.mode = 'settings'
args.model = 'yolo11m' # yolo 아무 버전의 모델 혹은 크기 관계없음

# %%
# 실행
# !python main.py --mode {args.mode} --model {args.model}
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLO Settings:
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "datasets",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": false,
#   "vscode_msg": true
# }

# %%
import torch

# 사용 가능한 디바이스 확인
if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
    print(f"사용 가능한 GPU 수: {num_gpus}")

    # 각 GPU에 대한 정보 출력
    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
        print(f"메모리 용량: {torch.cuda.get_device_properties(i).total_memory / 1024 ** 3:.2f} GB")
else:
    print("GPU를 사용할 수 없습니다. CPU를 사용합니다.")
# Out:
# 사용 가능한 GPU 수: 1
# GPU 0: NVIDIA A100-SXM4-40GB
# 메모리 용량: 39.56 GB

# %% [markdown]
# # 모델 학습

# %%
  args.mode = 'train'
  args.model = 'yolo11m'  # 모델 경로
  args.data = 'datasets/data.yaml'  # 데이터셋 설정 파일 경로
  args.imgsz = 640  # 이미지 크기
  args.epochs = 100  # 학습 에포크 수
  args.batch = 0.85 # 배치 크기
  args.optimizer = 'AdamW'  # 최적화 알고리즘
  args.patience = 20  # 조기 종료 기준
  args.cos_lr = True  # 코사인 학습률 스케줄러 사용
  args.verbose = True  # 상세 출력 모드

# %%
# train 모드 실행
# !python main.py --mode {args.mode} --model {args.model} --data {args.data} --imgsz {args.imgsz} \
--epochs {args.epochs} --batch {args.batch} --optimizer {args.optimizer} --patience {args.patience} \
--cos_lr {args.cos_lr} --verbose {args.verbose}
# Out:
# New https://pypi.org/project/ultralytics/8.3.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# engine/trainer: task=detect, mode=train, model=yolo11m.pt, data=datasets/data.yaml, epochs=100, time=None, patience=20, batch=0.85, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train11, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=True, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train11
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 14.8MB/s]
# Overriding model.yaml nc=80 with nc=14
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1421818  ultralytics.nn.modules.head.Detect           [14, [256, 512, 512]]
# YOLO11m summary: 409 layers, 20,063,802 parameters, 20,063,786 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train11', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# AutoBatch: Computing optimal batch size for imgsz=640 at 85.0% CUDA memory utilization.
# AutoBatch: CUDA:0 (NVIDIA A100-SXM4-40GB) 39.56G total, 0.21G reserved, 0.19G allocated, 39.16G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     20063802       68.24         0.765         84.25         325.3        (1, 3, 640, 640)                    list
#     20063802       136.5         1.300         44.34         81.38        (2, 3, 640, 640)                    list
#     20063802         273         2.313         45.02         71.12        (4, 3, 640, 640)                    list
#     20063802         546         4.299         52.42         69.31        (8, 3, 640, 640)                    list
#     20063802        1092         8.296         60.41         82.33       (16, 3, 640, 640)                    list
#     20063802        2184        16.263         75.45         120.2       (32, 3, 640, 640)                    list
#     20063802        4368        31.887         153.3         195.3       (64, 3, 640, 640)                    list
# AutoBatch: Using batch-size 66 for CUDA:0 33.35G/39.56G (84%) ✅
# train: Scanning /content/drive/MyDrive/gdgline-AI/model_trainning/datasets/train/labels... 5419 images, 54 backgrounds, 0 corrupt: 100% 5419/5419 [04:23<00:00, 20.53it/s]
# train: WARNING ⚠️ /content/drive/MyDrive/gdgline-AI/model_trainning/datasets/train/images/20241111_113214_61_jpg.rf.1bddeeacb63d90286043ccc391d89a50.jpg: 1 duplicate labels removed
# train: New cache created: /content/drive/MyDrive/gdgline-AI/model_trainning/datasets/train/labels.cache
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/drive/MyDrive/gdgline-AI/model_trainning/datasets/valid/labels... 1549 images, 23 backgrounds, 0 corrupt: 100% 1549/1549 [01:21<00:00, 19.01it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/gdgline-AI/model_trainning/datasets/valid/images/20241111_184930_49_jpg.rf.94c816753ae2f315bbcf2641532bec53.jpg: 1 duplicate labels removed
# val: New cache created: /content/drive/MyDrive/gdgline-AI/model_trainning/datasets/valid/labels.cache
# Plotting labels to runs/detect/train11/labels.jpg...
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.000515625), 112 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train11
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      33.9G      1.873      3.713      2.112         26        640: 100% 83/83 [00:41<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:05<00:00,  2.32it/s]
#                    all       1549       2663          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      33.8G      1.885      3.263      2.118         19        640: 100% 83/83 [00:41<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:09<00:00,  1.30it/s]
#                    all       1549       2663     0.0726    0.00752   0.000354   0.000108
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100
parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 12/12 [00:09<00:00,  1.31it/s]
#                    all       1549       2663      0.826      0.757      0.811      0.585
#        African_manatee         64         82      0.696       0.78       0.78      0.597
#                Arowana         26         36      0.765      0.722      0.825      0.573
#         Black_stingray         43         67      0.669      0.522       0.56      0.335
#    Blacktip_reef_shark         80        106      0.828      0.868      0.888      0.731
#    California_sea_lion        269        402      0.825      0.769       0.83      0.614
#              Clownfish        173        396      0.916      0.768      0.862       0.64
#             Garden_eel        125        407      0.827      0.703      0.817      0.551
#          Giant_grouper         83         88      0.812      0.943      0.926      0.783
#       Humboldt_penguin        171        382      0.851       0.76      0.808      0.518
# Leatherback_sea_turtle        229        269      0.922      0.855       0.91        0.6
#        Napoleon_wrasse         72         73      0.874      0.959      0.947      0.812
#                Piranha         10         68      0.886      0.459      0.607      0.316
#     Small_clawed_otter        154        246       0.84      0.764       0.83       0.52
#            Zebra_shark         39         41      0.855      0.732      0.766      0.603
# Speed: 0.1ms preprocess, 1.7ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/train11
# Training complete.

# %% [markdown]
# # 모델 이어서 학습하기
# - 중간에 얘기치 못하게 종료되었을때

# %%
args.mode = 'resume'
args.model = 'yolo11m'  # 모델 경로

# resume 모드 실행
# !python main.py --mode {args.mode} --model {args.model}

# %%
# resume 모드 실행
# !python main.py --mode {args.mode} --model {args.model}

# %% [markdown]
# # 모델 추가 학습하기

# %%
args.mode = 'continue'
args.model = 'last.pt'  # 모델 경로 (참고로 추가학습할때는 best.pt 말고 last.pt 사용)
args.data = 'datasets/data.yaml'  # 데이터셋 설정 파일 경로
args.additional_epochs = 50  # 추가 학습 에포크 수
args.batch = 34  # 배치 크기
args.optimizer = 'AdamW'  # 최적화 알고리즘
args.patience = 20  # 조기 종료 기준
args.cos_lr = True  # 코사인 학습률 스케줄러 사용
args.verbose = True  # 상세 출력 모드

# %%
# continue 모드 실행
# !python main.py --mode {args.mode} --model {args.model} --data {args.data} \
--additional_epochs {args.additional_epochs} --batch {args.batch} --optimizer {args.optimizer} \
--patience {args.patience}
# Out:
# New https://pypi.org/project/ultralytics/8.3.31 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.29 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# engine/trainer: task=detect, mode=train, model=last.pt, data=datasets/data.yaml, epochs=50, time=None, patience=20, batch=34, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=False, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1421818  ultralytics.nn.modules.head.Detect           [14, [256, 512, 512]]
# YOLO11m summary: 409 layers, 20,063,802 parameters, 20,063,786 gradients, 68.2 GFLOPs
#
# Transferred 649/649 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train3', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 66.4MB/s]
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/gdgline-AI/model_training/datasets/train/labels... 5419 images, 54 backgrounds, 0 corrupt: 100% 5419/5419 [03:55<00:00, 22.96it/s]
# train: WARNING ⚠️ /content/drive/MyDrive/gdgline-AI/model_training/datasets/train/images/20241111_113214_61_jpg.rf.1bddeeacb63d90286043ccc391d89a50.jpg: 1 duplicate labels removed
# train: New cache created: /content/drive/MyDrive/gdgline-AI/model_training/datasets/train/labels.cache
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/drive/MyDrive/gdgline-AI/model_training/datasets/valid/labels.cache... 1549 images, 23 backgrounds, 0 corrupt: 100% 1549/1549 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/gdgline-AI/model_training/datasets/valid/images/20241111_184930_49_jpg.rf.94c816753ae2f315bbcf2641532bec53.jpg: 1 duplicate labels removed
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.00053125), 112 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50        18G      1.037      1.061      1.354         45        640: 100% 160/160 [00:46<00:00,  3.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:07<00:00,  2
00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:07<00:00,  2.90it/s]
#                    all       1549       2663      0.823      0.775      0.826      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      17.9G      0.723     0.4977      1.178         29        640: 100% 160/160 [00:42<00:00,  3.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:07<00:00,  2.88it/s]
#                    all       1549       2663      0.836      0.775      0.827       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50        18G     0.7199     0.4973      1.177         45        640: 100% 160/160 [00:42<00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:08<00:00,  2.85it/s]
#                    all       1549       2663       0.86      0.751      0.826      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50        18G     0.7093     0.4845      1.164         15        640: 100% 160/160 [00:42<00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:08<00:00,  2.83it/s]
#                    all       1549       2663      0.837      0.776       0.83      0.611
#
# 50 epochs completed in 0.728 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 40.5MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 40.5MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics 8.3.29 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLO11m summary (fused): 303 layers, 20,040,826 parameters, 0 gradients, 67.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:09<00:00,  2.40it/s]
#                    all       1549       2663      0.836      0.776      0.831      0.611
# Speed: 0.1ms preprocess, 1.7ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/train3
# Continued training complete.

# %% [markdown]
# # 모델 검증

# %%
args.mode = 'evaluate'
args.model = 'best.pt'
args.data = 'datasets/data.yaml'

# %%
# valid 모드 실행
# !python main.py --mode {args.mode} --model {args.model} --data {args.data}
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLO11m summary (fused): 303 layers, 20,040,826 parameters, 0 gradients, 67.7 GFLOPs
# val: Scanning /content/drive/MyDrive/gdgline-AI/model_training/datasets/test/labels... 774 images, 8 backgrounds, 0 corrupt: 100% 774/774 [00:38<00:00, 19.99it/s]
# val: New cache created: /content/drive/MyDrive/gdgline-AI/model_training/datasets/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 49/49 [00:06<00:00,  7.62it/s]
#                    all        774       1378      0.799      0.786      0.836      0.606
#        African_manatee         30         39      0.693      0.744      0.848      0.653
#                Arowana         21         26      0.699      0.846       0.84      0.624
#         Black_stingray         22         45      0.643       0.44      0.526      0.271
#    Blacktip_reef_shark         60         71      0.897      0.901       0.94       0.75
#    California_sea_lion        142        192      0.803      0.844      0.885       0.67
#              Clownfish         68        175      0.884      0.787      0.842      0.604
#             Garden_eel         55        178      0.837      0.685       0.81      0.539
#          Giant_grouper         38         42      0.803      0.976      0.971      0.852
#       Humboldt_penguin         92        301      0.747      0.688      0.784      0.476
# Leatherback_sea_turtle        123        141      0.891      0.887      0.919      0.615
#        Napoleon_wrasse         24         24        0.8      0.917      0.927      0.763
#                Piranha          6         23      0.871      0.585      0.645      0.409
#     Small_clawed_otter         76        103      0.864      0.845      0.909      0.624
#            Zebra_shark         17         18      0.756      0.862      0.856      0.639
# Speed: 0.4ms preprocess, 2.8ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs/detect/val6
# Evaluation Metrics:
# 0.6064189692682923
# 0.8356950778556332
# 0.6805847273490441
# [    0.65253     0.62377     0.27107     0.75016     0.67038     0.60427     0.53937     0.85191     0.47599     0.61518     0.76322     0.40924     0.62398      0.6388]

# %% [markdown]
# # 모델 예측

# %%
args.mode = 'predict'
args.model = 'best.pt'
args.source = 'datasets/test/images/20241111_100059_133_jpg.rf.c9926247f21f71292fe502b56f74dde1.jpg'  # 예측할 이미지 소스 경로

# %%
# predict 모드 실행
# !python main.py --mode {args.mode} --model {args.model} --source {args.source}
# Out:
# image 1/1 /content/drive/MyDrive/gdgline-AI/model_training/datasets/test/images/20241111_100059_133_jpg.rf.c9926247f21f71292fe502b56f74dde1.jpg: 640x640 1 Napoleon_wrasse, 14.5ms
# Speed: 7.4ms preprocess, 14.5ms inference, 758.8ms postprocess per image at shape (1, 3, 640, 640)
# Prediction Results: [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'African_manatee', 1: 'Arowana', 2: 'Black_stingray', 3: 'Blacktip_reef_shark', 4: 'California_sea_lion', 5: 'Clownfish', 6: 'Garden_eel', 7: 'Giant_grouper', 8: 'Humboldt_penguin', 9: 'Leatherback_sea_turtle', 10: 'Napoleon_wrasse', 11: 'Piranha', 12: 'Small_clawed_otter', 13: 'Zebra_shark'}
# obb: None
# orig_img: array([[[178, 156, 138],
#         [185, 165, 147],
#         [186, 165, 150],
#         ...,
#         [172, 118,  55],
#         [170, 114,  49],
#         [169, 114,  47]],
#
#        [[180, 158, 140],
#         [183, 163, 145],
#         [185, 165, 148],
#         ...,
#         [176, 119,  57],
#         [167, 112,  45],
#         [161, 106,  37]],
#
#        [[177, 156, 135],
#         [178, 158, 140],
#         [184, 164, 147],
#         ...,
#         [184, 126,  61],
#         [168, 111,  42],
#         [156, 100,  29]],
#
#        ...,
#
#        [[ 96,  50,   9],
#         [111,  43,   0],
#         [147,  39,   0],
#         ...,
#         [255, 255, 216],
#         [255, 254, 215],
#         [255, 255, 214]],
#
#        [[ 96,  50,   9],
#         [114,  45,   2],
#         [157,  40,   0],
#         ...,
#         [255, 254, 210],
#         [255, 255, 209],
#         [255, 255, 207]],
#
#        [[ 96,  50,   9],
#         [117,  45,   3],
#         [163,  42,   0],
#         ...,
#         [252, 255, 206],
#         [253, 253, 205],
#         [253, 254, 204]]], dtype=uint8)
# orig_shape: (640, 640)
# path: '/content/drive/MyDrive/gdgline-AI/model_training/datasets/test/images/20241111_100059_133_jpg.rf.c9926247f21f71292fe502b56f74dde1.jpg'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 7.390737533569336, 'inference': 14.461517333984375, 'postprocess': 758.7721347808838}]

# %% [markdown]
# # 모델 내보내기

# %%
args.mode = 'export'
args.model = 'best.pt'
args.format = 'torchscript'  # 내보낼 형식 (torchscript, onnx 등)

# %%
# export 모드 실행
# !python main.py --mode {args.mode} --model {args.model} --format {args.format}
# Out:
# Ultralytics 8.3.29 🚀 Python-3.10.12 torch-2.5.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11m summary (fused): 303 layers, 20,040,826 parameters, 0 gradients, 67.7 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 18, 8400) (38.7 MB)
#
# TorchScript: starting export with torch 2.5.0+cu121...
# TorchScript: export success ✅ 3.7s, saved as 'best.torchscript' (77.1 MB)
#
# Export complete (6.4s)
# Results saved to /content/drive/MyDrive/gdgline-AI/model_training
# Predict:         yolo predict task=detect model=best.torchscript imgsz=640
# Validate:        yolo val task=detect model=best.torchscript imgsz=640 data=datasets/data.yaml
# Visualize:       https://netron.app
# Model exported as torchscript format for deployment
